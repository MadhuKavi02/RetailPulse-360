# %%
#09.05.2026

# %%
#Data Understanding

# %%
import pandas as pd

# %%
customer=pd.read_csv("Data Generation/KartZone_Customers.csv")

# %%
customer
# Out:
#      Customer_ID   Customer_Name   Age  Gender       City        State Region  \
# 0          C1001   Pallavi Gupta  36.0    Male   chennai    Tamil Nadu  South
# 1          C1002    Shreya Reddy -10.0       F     MUMBAI  maharashtra   West
# 2          C1003     PALLAVI DAS  32.0    Male        Hyd    Telangana  South
# 3          C1004    Shreya Patel  40.0       f  Hyderabad          NaN  south
# 4          C1005     Aarav Dubey  35.0  FEMALE     mumbai  Maharashtra   West
# ...          ...             ...   ...     ...        ...          ...    ...
# 1030         NaN             NaN   NaN     NaN        NaN          NaN    NaN
# 1031         NaN             NaN   NaN     NaN        NaN          NaN    NaN
# 1032         NaN             NaN   NaN     NaN        NaN          NaN    NaN
# 1033         NaN             NaN   NaN     NaN        NaN          NaN    NaN
# 1034         NaN             NaN   NaN     NaN        NaN          NaN    NaN
#
# ...

# %%
customer.shape
# Out:
# (1035, 17)

# %%
customer.columns
# Out:
# Index(['Customer_ID', 'Customer_Name', 'Age', 'Gender', 'City', 'State',
#        'Region', 'Customer_Segment', 'Registration_Date',
#        'Registration_Source', 'Last_Login_Date', 'Last_Order_Date', 'Email',
#        'Phone', 'Loyalty_Score', 'Preferred_Category',
#        'Newsletter_Subscribed'],
#       dtype='object')

# %%
customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1035 entries, 0 to 1034
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Customer_ID            1020 non-null   object
#  1   Customer_Name          1020 non-null   object
#  2   Age                    959 non-null    float64
#  3   Gender                 1020 non-null   object
#  4   City                   963 non-null    object
#  5   State                  910 non-null    object
#  6   Region                 912 non-null    object
#  7   Customer_Segment       1020 non-null   object
#  8   Registration_Date      1020 non-null   object
#  9   Registration_Source    954 non-null    object
#  10  Last_Login_Date        825 non-null    object
#  11  Last_Order_Date        794 non-null    object
#  12  Email                  769 non-null    object
#  13  Phone                  924 non-null    object
# ...

# %%
customer.isnull().sum()
# Out:
# Customer_ID               15
# Customer_Name             15
# Age                       76
# Gender                    15
# City                      72
# State                    125
# Region                   123
# Customer_Segment          15
# Registration_Date         15
# Registration_Source       81
# Last_Login_Date          210
# Last_Order_Date          241
# Email                    266
# Phone                    111
# Loyalty_Score            134
# Preferred_Category       196
# Newsletter_Subscribed    121
# dtype: int64

# %%
customer.isnull().sum().sum()
# Out:
# np.int64(1831)

# %%
customer.duplicated().sum()
# Out:
# np.int64(34)

# %%
customer.nunique()
# Out:
# Customer_ID              1000
# Customer_Name             909
# Age                        95
# Gender                     12
# City                       30
# State                      10
# Region                      6
# Customer_Segment           20
# Registration_Date         918
# Registration_Source        21
# Last_Login_Date           704
# Last_Order_Date           675
# Email                     589
# Phone                     677
# Loyalty_Score              98
# Preferred_Category         12
# Newsletter_Subscribed       8
# dtype: int64

# %%
customer.describe()
# Out:
#               Age  Loyalty_Score
# count  959.000000     901.000000
# mean    33.786236      44.462819
# std     32.386322      22.706044
# min    -20.000000       1.000000
# 25%     22.000000      28.000000
# 50%     31.000000      41.000000
# 75%     39.000000      62.000000
# max    199.000000     100.000000

# %%
customer[customer.duplicated(keep=False)]
# Out:
#      Customer_ID       Customer_Name    Age  Gender       City        State  \
# 76         C1077       Amrita Tiwari   35.0    male  New Delhi        delhi
# 136        C1137         SANJAY BOSE   24.0    MALE     MUMBAI  Maharashtra
# 280        C1281    Seema Chatterjee   36.0  FEMALE  HYDERABAD    Telangana
# 319        C1320    Kartik Venkatesh    NaN  Female  hyderabad    Telangana
# 411        C1412      Zara Venkatesh   24.0       M      Delhi        Delhi
# 513        C1514          KAVYA SHAH   23.0       1  bangalore    Karnataka
# 521        C1522       PALLAVI JOSHI   36.0       1      delhi        Delhi
# 626        C1627         KARTIK BOSE   29.0       F  hyderabad    Telangana
# 636        C1637        Ramesh Singh  198.0  FEMALE  BANGALORE    Karnataka
# 660        C1661          Ajay Verma   29.0       M     mumbai  Maharashtra
# 678        C1679         Sanjay Shah   48.0       M  HYDERABAD    Telangana
# ...

# %%
customer[customer.duplicated(['Customer_ID','Customer_Name','Phone'],keep=False)].sort_values(by='Customer_ID',ascending=True)
# Out:
#      Customer_ID       Customer_Name    Age  Gender       City        State  \
# 76         C1077       Amrita Tiwari   35.0    male  New Delhi        delhi
# 1011       C1077       Amrita Tiwari   35.0    male  New Delhi        delhi
# 136        C1137         SANJAY BOSE   24.0    MALE     MUMBAI  Maharashtra
# 1009       C1137         SANJAY BOSE   24.0    MALE     MUMBAI  Maharashtra
# 280        C1281    Seema Chatterjee   36.0  FEMALE  HYDERABAD    Telangana
# 1016       C1281    Seema Chatterjee   36.0  FEMALE  HYDERABAD    Telangana
# 1019       C1320    Kartik Venkatesh    NaN  Female  hyderabad    Telangana
# 319        C1320    Kartik Venkatesh    NaN  Female  hyderabad    Telangana
# 411        C1412      Zara Venkatesh   24.0       M      Delhi        Delhi
# 1004       C1412      Zara Venkatesh   24.0       M      Delhi        Delhi
# 513        C1514          KAVYA SHAH   23.0       1  bangalore    Karnataka
# ...

# %%
customer=customer.drop_duplicates(['Customer_ID','Customer_Name','Phone'])

# %%
customer[customer.duplicated(['Customer_ID','Customer_Name','Phone'],keep=False)].sort_values(by='Customer_ID',ascending=True)
# Out:
# Empty DataFrame
# Columns: [Customer_ID, Customer_Name, Age, Gender, City, State, Region, Customer_Segment, Registration_Date, Registration_Source, Last_Login_Date, Last_Order_Date, Email, Phone, Loyalty_Score, Preferred_Category, Newsletter_Subscribed]
# Index: []

# %%
customer=customer.reset_index(drop=True)

# %%
customer.isnull().all(axis=1).sum()
# Out:
# np.int64(1)

# %%
customer=customer.dropna(how='all')

# %%
customer.isnull().all(axis=1).sum()
# Out:
# np.int64(0)

# %%
customer.shape
# Out:
# (1000, 17)

# %%
(customer['Customer_Name'].str.strip()=="").sum()
# Out:
# np.int64(0)

# %%
customer['Customer_Name'].nunique()
# Out:
# 878

# %%
#Remove Extra Spaces
customer['Customer_Name']=(customer['Customer_Name'].astype(str).str.strip())

#Standardize Name Format
customer['Customer_Name']=(customer['Customer_Name'].str.title())

# %%
customer['Customer_Name'].nunique()
# Out:
# 807

# %%
customer['Customer_Name'].duplicated().sum()
# Out:
# np.int64(193)

# %%
customer[
    customer.duplicated(
        subset='Customer_Name',
        keep=False
    )
].sort_values(by='Customer_Name')[
    ['Customer_ID', 'Customer_Name']
]
# Out:
#     Customer_ID   Customer_Name
# 675       C1676     Aarav Mehta
# 293       C1294     Aarav Mehta
# 901       C1902       Aarav Rao
# 961       C1962       Aarav Rao
# 194       C1195       Aarav Sen
# ..          ...             ...
# 17        C1018        Zara Das
# 625       C1626     Zara Mishra
# 447       C1448     Zara Mishra
# 249       C1250  Zara Venkatesh
# 411       C1412  Zara Venkatesh
#
# [358 rows x 2 columns]

# %%
customer['Age'].isnull().sum()
# Out:
# np.int64(60)

# %%
customer['Age'].dtype
# Out:
# dtype('float64')

# %%
customer['Age'].describe()
# Out:
# count    940.000000
# mean      33.685106
# std       32.227275
# min      -20.000000
# 25%       22.000000
# 50%       31.000000
# 75%       39.000000
# max      199.000000
# Name: Age, dtype: float64

# %%
customer[(customer['Age']<0)|(customer['Age']>100)]
# Out:
#     Customer_ID    Customer_Name    Age  Gender       City        State  \
# 1         C1002     Shreya Reddy  -10.0       F     MUMBAI  maharashtra
# 15        C1016        Amit Iyer  197.0       f      Delhi        Delhi
# 24        C1025  Mr. Priya Gupta  136.0       f      Delhi        Delhi
# 39        C1040     Anjali Singh  -20.0       2     Bombay  Maharashtra
# 78        C1079      Zara Pillai   -8.0  FEMALE    CHENNAI   Tamil Nadu
# ..          ...              ...    ...     ...        ...          ...
# 949       C1950        Sonal Sen  122.0    male     MUMBAI  Maharashtra
# 967       C1968        Sneha Rao  166.0       F  BANGALORE    Karnataka
# 969       C1970      Isha Pillai   -8.0       f  NEW DELHI          NaN
# 970       C1971     Lakshmi Bose  167.0    MALE      Delhi        Delhi
# 992       C1993    Anjali Sharma  -10.0       F     MUMBAI  Maharashtra
#
#     Region Customer_Segment Registration_Date Registration_Source  \
# ...

# %%
customer[
    (customer['Age'] < 18) |
    (customer['Age'] > 80)
]
# Out:
#     Customer_ID       Customer_Name    Age  Gender       City        State  \
# 1         C1002        Shreya Reddy  -10.0       F     MUMBAI  maharashtra
# 10        C1011  Mr. Sonal Malhotra    0.0  female  Hyderabad    Telangana
# 15        C1016           Amit Iyer  197.0       f      Delhi        Delhi
# 24        C1025     Mr. Priya Gupta  136.0       f      Delhi        Delhi
# 37        C1038        Kiran Pillai    0.0       1   Banglore    Karnataka
# ..          ...                 ...    ...     ...        ...          ...
# 967       C1968           Sneha Rao  166.0       F  BANGALORE    Karnataka
# 969       C1970         Isha Pillai   -8.0       f  NEW DELHI          NaN
# 970       C1971        Lakshmi Bose  167.0    MALE      Delhi        Delhi
# 992       C1993       Anjali Sharma  -10.0       F     MUMBAI  Maharashtra
# 995       C1996       Vijay Agarwal    0.0    Male    chennai   Tamil Nadu
#
#     Region Customer_Segment Registration_Date Registration_Source  \
# ...

# %%
customer['Age'].value_counts().sort_index()
# Out:
# Age
# -20.0     0.001064
# -19.0     0.002128
# -18.0     0.002128
# -17.0     0.003191
# -15.0     0.004255
#             ...
#  194.0    0.001064
#  196.0    0.001064
#  197.0    0.002128
#  198.0    0.001064
#  199.0    0.002128
# Name: proportion, Length: 95, dtype: float64

# %%
customer
# Out:
#     Customer_ID  Customer_Name   Age  Gender       City        State Region  \
# 0         C1001  Pallavi Gupta  36.0    Male   chennai    Tamil Nadu  South
# 1         C1002   Shreya Reddy -10.0       F     MUMBAI  maharashtra   West
# 2         C1003    Pallavi Das  32.0    Male        Hyd    Telangana  South
# 3         C1004   Shreya Patel  40.0       f  Hyderabad          NaN  south
# 4         C1005    Aarav Dubey  35.0  FEMALE     mumbai  Maharashtra   West
# ..          ...            ...   ...     ...        ...          ...    ...
# 995       C1996  Vijay Agarwal   0.0    Male    chennai   Tamil Nadu  south
# 996       C1997    Kavya Singh  43.0    MALE     MUMBAI  Maharashtra   West
# 997       C1998    Aarav Joshi  32.0       1  Hyderabad    Telangana  South
# 998       C1999   Tanvi Tiwari  32.0    Male     Delhi         Delhi    NaN
# 999       C2000  Vishal Sharma  32.0  Female  New Delhi        Delhi    NaN
#
# ...

# %%
customer[
    (customer['Age'] >= 25) &
    (customer['Age'] <= 35)
].shape[0]
# Out:
# 322

# %%
# Out:
# 0        Pallavi Gupta
# 1         Shreya Reddy
# 2          PALLAVI DAS
# 3         Shreya Patel
# 4          Aarav Dubey
#              ...
# 1030               NaN
# 1031               NaN
# 1032               NaN
# 1033               NaN
# 1034               NaN
# Name: Customer_Name, Length: 1035, dtype: object

# %%
customer['Gender'].value_counts()
# Out:
# Gender
# F         105
# 2          97
# M          93
# Female     88
# Male       86
# female     85
# 1          84
# f          82
# male       82
# m          81
# FEMALE     72
# MALE       65
# Name: count, dtype: int64
